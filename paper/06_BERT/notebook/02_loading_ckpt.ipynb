# %%
import torch
from glob import glob

# %%
ckpt_path = glob('~/torch_study/paper/06_BERT/lightning_logs/version_244/checkpoints/*')

# %%
ckpt_path
# Out:
# ['~/torch_study/paper/06_BERT/lightning_logs/version_244/checkpoints/epoch=22-step=6715.ckpt']

# %%
torch.load(ckpt_path[0])['state_dict']
# Out:
# OrderedDict([('encoder.tok_embedding.weight',
#               tensor([[ 0.0089, -0.0118,  0.0079,  ..., -0.0255, -0.0369,  0.0417],
#                       [ 0.0305,  0.1096,  0.0442,  ...,  0.0278, -0.0231, -0.0123],
#                       [-0.0356,  0.0074, -0.0600,  ...,  0.0173,  0.0397, -0.0190],
#                       ...,
#                       [ 0.0142,  0.0050,  0.0034,  ..., -0.0105, -0.0063, -0.0177],
#                       [ 0.0117, -0.0306, -0.0071,  ...,  0.0087,  0.0198,  0.0019],
#                       [ 0.0409, -0.0371,  0.0022,  ...,  0.0138,  0.0043,  0.0119]],
#                      device='cuda:0')),
#              ('encoder.pos_embedding.weight',
#               tensor([[-0.0273, -0.0087, -0.0301,  ..., -0.0100,  0.0433,  0.0007],
#                       [ 0.0617,  0.0642,  0.0353,  ...,  0.0703,  0.0027, -0.0140],
#                       [-0.0705, -0.0301,  0.0575,  ...,  0.1021,  0.0155,  0.0470],
#                       ...,
# ...
